# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('soil.csv')

# %%
df.head()
# Out:
#    Dist Code            Year  State Code    State Name Dist Name  \
# 0          1  Not Applicable          14  Chhattisgarh      Durg
# 1          2  Not Applicable          14  Chhattisgarh    Bastar
# 2          3  Not Applicable          14  Chhattisgarh    Raipur
# 3          4  Not Applicable          14  Chhattisgarh  Bilaspur
# 4          5  Not Applicable          14  Chhattisgarh   Raigarh
#
#                          SOIL TYPE PERCENT (Percent)
# 0        LOAMY ALFISOLS - 60% ; USTALF/USTOLLS - 40%
# 1                               LOAMY ALFISOL - 100%
# 2  USTALF/USTOLLS - 50% ; LOAMY ALFISOLS - 25% ; ...
# 3                              USTALF/USTOLLS - 100%
# 4                              USTALF/USTOLLS - 100%

# %%
for col in df.columns: 
    print(col)
# Out:
# Dist Code
# Year
# State Code
# State Name
# Dist Name
# SOIL TYPE PERCENT (Percent)

# %%
df.rename(columns = {'SOIL TYPE PERCENT (Percent)':'Soil'}, inplace = True)

# %%
df
# Out:
#      Dist Code            Year  State Code    State Name  Dist Name  \
# 0            1  Not Applicable          14  Chhattisgarh       Durg
# 1            2  Not Applicable          14  Chhattisgarh     Bastar
# 2            3  Not Applicable          14  Chhattisgarh     Raipur
# 3            4  Not Applicable          14  Chhattisgarh   Bilaspur
# 4            5  Not Applicable          14  Chhattisgarh    Raigarh
# ..         ...             ...         ...           ...        ...
# 308        914  Not Applicable          15     Jharkhand    Dhanbad
# 309        915  Not Applicable          15     Jharkhand    Palamau
# 310        916  Not Applicable          15     Jharkhand     Ranchi
# 311        917  Not Applicable          15     Jharkhand  Singhbhum
# 312        999  Not Applicable          11    Tamil Nadu    Chennai
#
#                                                   Soil
# 0          LOAMY ALFISOLS - 60% ; USTALF/USTOLLS - 40%
# ...

# %%
df[['First','Last','Third']]= df.Soil.str.split(";",expand=True)
df
# Out:
#      Dist Code            Year  State Code    State Name  Dist Name  \
# 0            1  Not Applicable          14  Chhattisgarh       Durg
# 1            2  Not Applicable          14  Chhattisgarh     Bastar
# 2            3  Not Applicable          14  Chhattisgarh     Raipur
# 3            4  Not Applicable          14  Chhattisgarh   Bilaspur
# 4            5  Not Applicable          14  Chhattisgarh    Raigarh
# ..         ...             ...         ...           ...        ...
# 308        914  Not Applicable          15     Jharkhand    Dhanbad
# 309        915  Not Applicable          15     Jharkhand    Palamau
# 310        916  Not Applicable          15     Jharkhand     Ranchi
# 311        917  Not Applicable          15     Jharkhand  Singhbhum
# 312        999  Not Applicable          11    Tamil Nadu    Chennai
#
#                                                   Soil                  First  \
# ...

# %%
df[['f','l']]= df.First.str.split("-",expand=True)
df
# Out:
#      Dist Code            Year  State Code    State Name  Dist Name  \
# 0            1  Not Applicable          14  Chhattisgarh       Durg
# 1            2  Not Applicable          14  Chhattisgarh     Bastar
# 2            3  Not Applicable          14  Chhattisgarh     Raipur
# 3            4  Not Applicable          14  Chhattisgarh   Bilaspur
# 4            5  Not Applicable          14  Chhattisgarh    Raigarh
# ..         ...             ...         ...           ...        ...
# 308        914  Not Applicable          15     Jharkhand    Dhanbad
# 309        915  Not Applicable          15     Jharkhand    Palamau
# 310        916  Not Applicable          15     Jharkhand     Ranchi
# 311        917  Not Applicable          15     Jharkhand  Singhbhum
# 312        999  Not Applicable          11    Tamil Nadu    Chennai
#
#                                                   Soil                  First  \
# ...

# %%
df.groupby('f').count()
# Out:
#                  Dist Code  Year  State Code  State Name  Dist Name  Soil  \
# f
# DYSTROPEPTS              2     2           2           2          2     2
# FLUVENTS                 7     7           7           7          7     7
# INCEPTISOLS             86    86          86          86         86    86
# INNCEPTISOLS             1     1           1           1          1     1
# LOAMY ALFISOL            2     2           2           2          2     2
# LOAMY ALFISOLS           5     5           5           5          5     5
# ORTHENTS                 1     1           1           1          1     1
# ORTHIDS                 25    25          25          25         25    25
# PSAMMENTS                3     3           3           3          3     3
# PSSAMENTS               11    11          11          11         11    11
# PSSAMNETS                2     2           2           2          2     2
# SANDY ALFISOL           25    25          25          25         25    25
# ...

# %%
df = pd.read_csv('soil.csv')
df.rename(columns = {'SOIL TYPE PERCENT (Percent)':'soil_per'}, inplace = True)

# %%
df
# Out:
#      Dist Code            Year  State Code    State Name  Dist Name  \
# 0            1  Not Applicable          14  Chhattisgarh       Durg
# 1            2  Not Applicable          14  Chhattisgarh     Bastar
# 2            3  Not Applicable          14  Chhattisgarh     Raipur
# 3            4  Not Applicable          14  Chhattisgarh   Bilaspur
# 4            5  Not Applicable          14  Chhattisgarh    Raigarh
# ..         ...             ...         ...           ...        ...
# 308        914  Not Applicable          15     Jharkhand    Dhanbad
# 309        915  Not Applicable          15     Jharkhand    Palamau
# 310        916  Not Applicable          15     Jharkhand     Ranchi
# 311        917  Not Applicable          15     Jharkhand  Singhbhum
# 312        999  Not Applicable          11    Tamil Nadu    Chennai
#
#                                               soil_per
# 0          LOAMY ALFISOLS - 60% ; USTALF/USTOLLS - 40%
# ...

# %%
df['comma_count'] = df.soil_per.str.count(';')
column = df["comma_count"]
max_value = column.max()
print(max_value)
# Out:
# 2.0

# %%
df[['First','Second','Third']]= df.soil_per.str.split(";",expand=True)

# %%
df[['f','l']]= df.First.str.split("-",expand=True)

# %%
unique=df['f'].unique()
unique
# Out:
# array(['LOAMY ALFISOLS ', 'LOAMY ALFISOL ', 'USTALF/USTOLLS ',
#        'VERTIC SOILS ', 'VERTISOLS ', 'ORTHIDS ', 'SANDY ALFISOL ',
#        'VERTIC SOLS ', 'VRTIC SOILS ', 'UDUPTS/UDALFS ', 'INCEPTISOLS ',
#        'PSSAMENTS ', 'PSSAMNETS ', 'UDOLLS/UDALFS ', 'INNCEPTISOLS ',
#        'FLUVENTS', 'USTALFS', 'UDALFS', nan, 'PSAMMENTS', 'ORTHENTS',
#        'DYSTROPEPTS'], dtype=object)

# %%
df[['f2','l2']]= df.Second.str.split("-",expand=True)

# %%
np.append(unique,df['f2'].unique())
# Out:
# array(['LOAMY ALFISOLS ', 'LOAMY ALFISOL ', 'USTALF/USTOLLS ',
#        'VERTIC SOILS ', 'VERTISOLS ', 'ORTHIDS ', 'SANDY ALFISOL ',
#        'VERTIC SOLS ', 'VRTIC SOILS ', 'UDUPTS/UDALFS ', 'INCEPTISOLS ',
#        'PSSAMENTS ', 'PSSAMNETS ', 'UDOLLS/UDALFS ', 'INNCEPTISOLS ',
#        'FLUVENTS', 'USTALFS', 'UDALFS', nan, 'PSAMMENTS', 'ORTHENTS',
#        'DYSTROPEPTS', ' USTALF/USTOLLS ', None, ' LOAMY ALFISOLS ',
#        ' VERTISOLS ', ' VERTIC SOILS ', ' INCEPTISOLS ', ' VERRTISOLS ',
#        ' SANDY ALFISOL ', ' ORTHIDS ', ' SANDY ALFISOLS ',
#        ' UDUPTS/UDALFS ', ' VERTI SOLS ', ' PSSAMENTS ', ' VERTIC OSILS ',
#        ' PSSAMNETS ', ' UDOLLS/UDALFS ', nan, ' USTALF/USTOLLS'],
#       dtype=object)

# %%
df[['f3','l3']]= df.Third.str.split("-",expand=True)

# %%
np.append(unique,df['f3'].unique())
# Out:
# array(['LOAMY ALFISOLS ', 'LOAMY ALFISOL ', 'USTALF/USTOLLS ',
#        'VERTIC SOILS ', 'VERTISOLS ', 'ORTHIDS ', 'SANDY ALFISOL ',
#        'VERTIC SOLS ', 'VRTIC SOILS ', 'UDUPTS/UDALFS ', 'INCEPTISOLS ',
#        'PSSAMENTS ', 'PSSAMNETS ', 'UDOLLS/UDALFS ', 'INNCEPTISOLS ',
#        'FLUVENTS', 'USTALFS', 'UDALFS', nan, 'PSAMMENTS', 'ORTHENTS',
#        'DYSTROPEPTS', None, ' VERTISOLS ', ' USTALF/USTOLLS ',
#        ' SANDY ALFISOL ', ' ORTHIDS ', ' VERTIC SOILS ',
#        ' UDUPTS/UDALFS ', ' VERTIC SOLS ', nan], dtype=object)

# %%
unique = unique.astype(str)
np.unique(unique)
# Out:
# array(['DYSTROPEPTS', 'FLUVENTS', 'INCEPTISOLS ', 'INNCEPTISOLS ',
#        'LOAMY ALFISOL ', 'LOAMY ALFISOLS ', 'ORTHENTS', 'ORTHIDS ',
#        'PSAMMENTS', 'PSSAMENTS ', 'PSSAMNETS ', 'SANDY ALFISOL ',
#        'UDALFS', 'UDOLLS/UDALFS ', 'UDUPTS/UDALFS ', 'USTALF/USTOLLS ',
#        'USTALFS', 'VERTIC SOILS ', 'VERTIC SOLS ', 'VERTISOLS ',
#        'VRTIC SOILS ', 'nan'], dtype='<U15')

# %%
df = pd.read_csv('soil.csv')
df.rename(columns = {'SOIL TYPE PERCENT (Percent)':'Soil'}, inplace = True)

# %%
df['comma_count'] = df.Soil.str.count(';')
column = df["comma_count"]
max_value = column.max()
print(max_value)
# Out:
# 2.0

# %%
df[['First','Second','Third']]= df.Soil.str.split(";",expand=True)

# %%
df[['f','l']]= df.First.str.split("-",expand=True)
unique=df['f'].unique()
print(unique)
# Out:
# ['LOAMY ALFISOLS ' 'LOAMY ALFISOL ' 'USTALF/USTOLLS ' 'VERTIC SOILS '
#  'VERTISOLS ' 'ORTHIDS ' 'SANDY ALFISOL ' 'VERTIC SOLS ' 'VRTIC SOILS '
#  'UDUPTS/UDALFS ' 'INCEPTISOLS ' 'PSSAMENTS ' 'PSSAMNETS '
#  'UDOLLS/UDALFS ' 'INNCEPTISOLS ' 'FLUVENTS' 'USTALFS' 'UDALFS' nan
#  'PSAMMENTS' 'ORTHENTS' 'DYSTROPEPTS']

# %%
df[['f2','l2']]= df.Second.str.split("-",expand=True)
np.append(unique,df['f2'].unique())
# Out:
# array(['LOAMY ALFISOLS ', 'LOAMY ALFISOL ', 'USTALF/USTOLLS ',
#        'VERTIC SOILS ', 'VERTISOLS ', 'ORTHIDS ', 'SANDY ALFISOL ',
#        'VERTIC SOLS ', 'VRTIC SOILS ', 'UDUPTS/UDALFS ', 'INCEPTISOLS ',
#        'PSSAMENTS ', 'PSSAMNETS ', 'UDOLLS/UDALFS ', 'INNCEPTISOLS ',
#        'FLUVENTS', 'USTALFS', 'UDALFS', nan, 'PSAMMENTS', 'ORTHENTS',
#        'DYSTROPEPTS', ' USTALF/USTOLLS ', None, ' LOAMY ALFISOLS ',
#        ' VERTISOLS ', ' VERTIC SOILS ', ' INCEPTISOLS ', ' VERRTISOLS ',
#        ' SANDY ALFISOL ', ' ORTHIDS ', ' SANDY ALFISOLS ',
#        ' UDUPTS/UDALFS ', ' VERTI SOLS ', ' PSSAMENTS ', ' VERTIC OSILS ',
#        ' PSSAMNETS ', ' UDOLLS/UDALFS ', nan, ' USTALF/USTOLLS'],
#       dtype=object)

# %%
df[['f3','l3']]= df.Third.str.split("-",expand=True)
np.append(unique,df['f2'].unique())
# Out:
# array(['LOAMY ALFISOLS ', 'LOAMY ALFISOL ', 'USTALF/USTOLLS ',
#        'VERTIC SOILS ', 'VERTISOLS ', 'ORTHIDS ', 'SANDY ALFISOL ',
#        'VERTIC SOLS ', 'VRTIC SOILS ', 'UDUPTS/UDALFS ', 'INCEPTISOLS ',
#        'PSSAMENTS ', 'PSSAMNETS ', 'UDOLLS/UDALFS ', 'INNCEPTISOLS ',
#        'FLUVENTS', 'USTALFS', 'UDALFS', nan, 'PSAMMENTS', 'ORTHENTS',
#        'DYSTROPEPTS', ' USTALF/USTOLLS ', None, ' LOAMY ALFISOLS ',
#        ' VERTISOLS ', ' VERTIC SOILS ', ' INCEPTISOLS ', ' VERRTISOLS ',
#        ' SANDY ALFISOL ', ' ORTHIDS ', ' SANDY ALFISOLS ',
#        ' UDUPTS/UDALFS ', ' VERTI SOLS ', ' PSSAMENTS ', ' VERTIC OSILS ',
#        ' PSSAMNETS ', ' UDOLLS/UDALFS ', nan, ' USTALF/USTOLLS'],
#       dtype=object)

# %%
df = pd.read_csv('soil2.csv', index_col='Dist Code')
df
# Out:
#                      Year  State Code      State Name    Dist Name  \
# Dist Code
# 1          Not Applicable          14    Chhattisgarh         Durg
# 2          Not Applicable          14    Chhattisgarh       Bastar
# 3          Not Applicable          14    Chhattisgarh       Raipur
# 4          Not Applicable          14    Chhattisgarh     Bilaspur
# 5          Not Applicable          14    Chhattisgarh      Raigarh
# 6          Not Applicable          14    Chhattisgarh      Surguja
# 7          Not Applicable           6  Madhya Pradesh     Jabalpur
# 8          Not Applicable           6  Madhya Pradesh     Balaghat
# 9          Not Applicable           6  Madhya Pradesh   Chhindwara
# 10         Not Applicable           6  Madhya Pradesh  Narsinghpur
#
#                                                     soil_per
# Dist Code
# 1                LOAMY ALFISOLS - 60% ; USTALF/USTOLLS - 40%
# 2                                       LOAMY ALFISOL - 100%
# ...

# %%
del df['Year']

# %%
df
# Out:
#            State Code      State Name    Dist Name  \
# Dist Code
# 1                  14    Chhattisgarh         Durg
# 2                  14    Chhattisgarh       Bastar
# 3                  14    Chhattisgarh       Raipur
# 4                  14    Chhattisgarh     Bilaspur
# 5                  14    Chhattisgarh      Raigarh
# 6                  14    Chhattisgarh      Surguja
# 7                   6  Madhya Pradesh     Jabalpur
# 8                   6  Madhya Pradesh     Balaghat
# 9                   6  Madhya Pradesh   Chhindwara
# 10                  6  Madhya Pradesh  Narsinghpur
#
#                                                     soil_per
# Dist Code
# 1                LOAMY ALFISOLS - 60% ; USTALF/USTOLLS - 40%
# 2                                       LOAMY ALFISOL - 100%
# 3          USTALF/USTOLLS - 50% ; LOAMY ALFISOLS - 25% ; ...
# 4                                      USTALF/USTOLLS - 100%
# 5                                      USTALF/USTOLLS - 100%
# ...

# %%
df[['First','Second','Third']]= df.soil_per.str.split(";",expand=True)
df[['f1','l1']]= df.First.str.split("-",expand=True)
df[['f2','l2']]= df.Second.str.split("-",expand=True)
df[['f3','l3']]= df.Third.str.split("-",expand=True)

# %%
df
# Out:
#            State Code      State Name    Dist Name  \
# Dist Code
# 1                  14    Chhattisgarh         Durg
# 2                  14    Chhattisgarh       Bastar
# 3                  14    Chhattisgarh       Raipur
# 4                  14    Chhattisgarh     Bilaspur
# 5                  14    Chhattisgarh      Raigarh
# 6                  14    Chhattisgarh      Surguja
# 7                   6  Madhya Pradesh     Jabalpur
# 8                   6  Madhya Pradesh     Balaghat
# 9                   6  Madhya Pradesh   Chhindwara
# 10                  6  Madhya Pradesh  Narsinghpur
#
#                                                     soil_per  \
# Dist Code
# 1                LOAMY ALFISOLS - 60% ; USTALF/USTOLLS - 40%
# 2                                       LOAMY ALFISOL - 100%
# 3          USTALF/USTOLLS - 50% ; LOAMY ALFISOLS - 25% ; ...
# 4                                      USTALF/USTOLLS - 100%
# 5                                      USTALF/USTOLLS - 100%
# ...

# %%
del df['First']
del df['Second']
del df['Third']

# %%
df
# Out:
#            State Code      State Name    Dist Name  \
# Dist Code
# 1                  14    Chhattisgarh         Durg
# 2                  14    Chhattisgarh       Bastar
# 3                  14    Chhattisgarh       Raipur
# 4                  14    Chhattisgarh     Bilaspur
# 5                  14    Chhattisgarh      Raigarh
# 6                  14    Chhattisgarh      Surguja
# 7                   6  Madhya Pradesh     Jabalpur
# 8                   6  Madhya Pradesh     Balaghat
# 9                   6  Madhya Pradesh   Chhindwara
# 10                  6  Madhya Pradesh  Narsinghpur
#
#                                                     soil_per               f1  \
# Dist Code
# 1                LOAMY ALFISOLS - 60% ; USTALF/USTOLLS - 40%  LOAMY ALFISOLS
# 2                                       LOAMY ALFISOL - 100%   LOAMY ALFISOL
# 3          USTALF/USTOLLS - 50% ; LOAMY ALFISOLS - 25% ; ...  USTALF/USTOLLS
# ...

# %%
df.sort_values("f1", inplace = True) 
df
# Out:
#            State Code      State Name    Dist Name  \
# Dist Code
# 2                  14    Chhattisgarh       Bastar
# 1                  14    Chhattisgarh         Durg
# 3                  14    Chhattisgarh       Raipur
# 4                  14    Chhattisgarh     Bilaspur
# 5                  14    Chhattisgarh      Raigarh
# 6                  14    Chhattisgarh      Surguja
# 7                   6  Madhya Pradesh     Jabalpur
# 8                   6  Madhya Pradesh     Balaghat
# 9                   6  Madhya Pradesh   Chhindwara
# 10                  6  Madhya Pradesh  Narsinghpur
#
#                                                     soil_per               f1  \
# Dist Code
# 2                                       LOAMY ALFISOL - 100%   LOAMY ALFISOL
# 1                LOAMY ALFISOLS - 60% ; USTALF/USTOLLS - 40%  LOAMY ALFISOLS
# 3          USTALF/USTOLLS - 50% ; LOAMY ALFISOLS - 25% ; ...  USTALF/USTOLLS
# ...

# %%
df[df['f1'] == 'USTALF/USTOLLS ']
# Out:
#            State Code    State Name Dist Name  \
# Dist Code
# 3                  14  Chhattisgarh    Raipur
# 4                  14  Chhattisgarh  Bilaspur
# 5                  14  Chhattisgarh   Raigarh
# 6                  14  Chhattisgarh   Surguja
#
#                                                     soil_per               f1  \
# Dist Code
# 3          USTALF/USTOLLS - 50% ; LOAMY ALFISOLS - 25% ; ...  USTALF/USTOLLS
# 4                                      USTALF/USTOLLS - 100%  USTALF/USTOLLS
# 5                                      USTALF/USTOLLS - 100%  USTALF/USTOLLS
# 6                                      USTALF/USTOLLS - 100%  USTALF/USTOLLS
#
#               l1                f2     l2           f3    l3
# Dist Code
# 3           50%    LOAMY ALFISOLS    25%    VERTISOLS    15%
# 4           100%              None   None         None  None
# 5           100%              None   None         None  None
# 6           100%              None   None         None  None

# %%
del df['soil_per']

# %%
df
# Out:
#            State Code      State Name    Dist Name               f1     l1  \
# Dist Code
# 2                  14    Chhattisgarh       Bastar   LOAMY ALFISOL    100%
# 1                  14    Chhattisgarh         Durg  LOAMY ALFISOLS    60%
# 3                  14    Chhattisgarh       Raipur  USTALF/USTOLLS    50%
# 4                  14    Chhattisgarh     Bilaspur  USTALF/USTOLLS    100%
# 5                  14    Chhattisgarh      Raigarh  USTALF/USTOLLS    100%
# 6                  14    Chhattisgarh      Surguja  USTALF/USTOLLS    100%
# 7                   6  Madhya Pradesh     Jabalpur    VERTIC SOILS    85%
# 8                   6  Madhya Pradesh     Balaghat    VERTIC SOILS    85%
# 9                   6  Madhya Pradesh   Chhindwara    VERTIC SOILS    85%
# 10                  6  Madhya Pradesh  Narsinghpur       VERTISOLS    80%
#
#                          f2     l2           f3    l3
# Dist Code
# 2                      None   None         None  None
# ...

# %%
a = df[df['f1'] == 'USTALF/USTOLLS '].l1
a = a.append(df[df['f2'] == ' USTALF/USTOLLS '].l2)
a = a.append(df[df['f3'] == ' USTALF/USTOLLS '].l3)
df = df.assign(USTALF_USTOLLS = a)
df
# Out:
#            State Code      State Name    Dist Name               f1     l1  \
# Dist Code
# 2                  14    Chhattisgarh       Bastar   LOAMY ALFISOL    100%
# 1                  14    Chhattisgarh         Durg  LOAMY ALFISOLS    60%
# 3                  14    Chhattisgarh       Raipur  USTALF/USTOLLS    50%
# 4                  14    Chhattisgarh     Bilaspur  USTALF/USTOLLS    100%
# 5                  14    Chhattisgarh      Raigarh  USTALF/USTOLLS    100%
# 6                  14    Chhattisgarh      Surguja  USTALF/USTOLLS    100%
# 7                   6  Madhya Pradesh     Jabalpur    VERTIC SOILS    85%
# 8                   6  Madhya Pradesh     Balaghat    VERTIC SOILS    85%
# 9                   6  Madhya Pradesh   Chhindwara    VERTIC SOILS    85%
# 10                  6  Madhya Pradesh  Narsinghpur       VERTISOLS    80%
#
#                          f2     l2           f3    l3 USTALF_USTOLLS
# Dist Code
# ...

# %%
# Out:
# Dist Code
# 3     50%
# 4     100%
# 5     100%
# 6     100%
# Name: l1, dtype: object

# %%
a = a.append(df[df['f2'] == ' USTALF/USTOLLS '].l2)
a
# Out:
# Dist Code
# 3     50%
# 4     100%
# 5     100%
# 6     100%
# 1      40%
# dtype: object

# %%
a = a.append(df[df['f3'] == ' USTALF/USTOLLS '].l3)
a
# Out:
# Dist Code
# 3     50%
# 4     100%
# 5     100%
# 6     100%
# 1      40%
# dtype: object

# %%
# Out:
#            State Code      State Name    Dist Name               f1     l1  \
# Dist Code
# 2                  14    Chhattisgarh       Bastar   LOAMY ALFISOL    100%
# 1                  14    Chhattisgarh         Durg  LOAMY ALFISOLS    60%
# 3                  14    Chhattisgarh       Raipur  USTALF/USTOLLS    50%
# 4                  14    Chhattisgarh     Bilaspur  USTALF/USTOLLS    100%
# 5                  14    Chhattisgarh      Raigarh  USTALF/USTOLLS    100%
# 6                  14    Chhattisgarh      Surguja  USTALF/USTOLLS    100%
# 7                   6  Madhya Pradesh     Jabalpur    VERTIC SOILS    85%
# 8                   6  Madhya Pradesh     Balaghat    VERTIC SOILS    85%
# 9                   6  Madhya Pradesh   Chhindwara    VERTIC SOILS    85%
# 10                  6  Madhya Pradesh  Narsinghpur       VERTISOLS    80%
#
#                          f2     l2           f3    l3     ad
# Dist Code
# 2                      None   None         None  None    NaN
# ...

# %%
df['l1'] = list(map(lambda x: x[:-1], df['l1'].values))

# %%
df
# Out:
#            State Code      State Name    Dist Name               f1   l1  \
# Dist Code
# 2                  14    Chhattisgarh       Bastar   LOAMY ALFISOL    10
# 1                  14    Chhattisgarh         Durg  LOAMY ALFISOLS    60
# 3                  14    Chhattisgarh       Raipur  USTALF/USTOLLS    50
# 4                  14    Chhattisgarh     Bilaspur  USTALF/USTOLLS    10
# 5                  14    Chhattisgarh      Raigarh  USTALF/USTOLLS    10
# 6                  14    Chhattisgarh      Surguja  USTALF/USTOLLS    10
# 7                   6  Madhya Pradesh     Jabalpur    VERTIC SOILS    85
# 8                   6  Madhya Pradesh     Balaghat    VERTIC SOILS    85
# 9                   6  Madhya Pradesh   Chhindwara    VERTIC SOILS    85
# 10                  6  Madhya Pradesh  Narsinghpur       VERTISOLS    80
#
#                          f2     l2           f3    l3 USTALF_USTOLLS
# Dist Code
# 2                      None   None         None  None            NaN
# ...

# %%
df['l1'] = [float(x) for x in df['l1'].values]
df
# Out:
#            State Code      State Name    Dist Name               f1    l1  \
# Dist Code
# 2                  14    Chhattisgarh       Bastar   LOAMY ALFISOL   10.0
# 1                  14    Chhattisgarh         Durg  LOAMY ALFISOLS   60.0
# 3                  14    Chhattisgarh       Raipur  USTALF/USTOLLS   50.0
# 4                  14    Chhattisgarh     Bilaspur  USTALF/USTOLLS   10.0
# 5                  14    Chhattisgarh      Raigarh  USTALF/USTOLLS   10.0
# 6                  14    Chhattisgarh      Surguja  USTALF/USTOLLS   10.0
# 7                   6  Madhya Pradesh     Jabalpur    VERTIC SOILS   85.0
# 8                   6  Madhya Pradesh     Balaghat    VERTIC SOILS   85.0
# 9                   6  Madhya Pradesh   Chhindwara    VERTIC SOILS   85.0
# 10                  6  Madhya Pradesh  Narsinghpur       VERTISOLS   80.0
#
#                          f2     l2           f3    l3 USTALF_USTOLLS
# Dist Code
# ...

# %%
df['l1'] = list(map(lambda x: x/100, df['l1'].values))
df
# Out:
#            State Code      State Name    Dist Name               f1    l1  \
# Dist Code
# 2                  14    Chhattisgarh       Bastar   LOAMY ALFISOL   0.10
# 1                  14    Chhattisgarh         Durg  LOAMY ALFISOLS   0.60
# 3                  14    Chhattisgarh       Raipur  USTALF/USTOLLS   0.50
# 4                  14    Chhattisgarh     Bilaspur  USTALF/USTOLLS   0.10
# 5                  14    Chhattisgarh      Raigarh  USTALF/USTOLLS   0.10
# 6                  14    Chhattisgarh      Surguja  USTALF/USTOLLS   0.10
# 7                   6  Madhya Pradesh     Jabalpur    VERTIC SOILS   0.85
# 8                   6  Madhya Pradesh     Balaghat    VERTIC SOILS   0.85
# 9                   6  Madhya Pradesh   Chhindwara    VERTIC SOILS   0.85
# 10                  6  Madhya Pradesh  Narsinghpur       VERTISOLS   0.80
#
#                          f2     l2           f3    l3 USTALF_USTOLLS
# Dist Code
# ...
